# %%
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn

# %%
import piplite
await piplite.install('seaborn')

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,PolynomialFeatures
from sklearn.linear_model import LinearRegression
# %matplotlib inline

# %%
from pyodide.http import pyfetch

async def download(url, filename):
    response = await pyfetch(url)
    if response.status == 200:
        with open(filename, "wb") as f:
            f.write(await response.bytes())

# URL of the dataset
filepath = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/' \
           'IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/FinalModule_Coursera/data/kc_house_data_NaN.csv'

await download(filepath, "housing.csv")

# %%
df = pd.read_csv("housing.csv")

# %%
df.head()
# Out:
#    Unnamed: 0          id             date     price  bedrooms  bathrooms  \
# 0           0  7129300520  20141013T000000  221900.0       3.0       1.00
# 1           1  6414100192  20141209T000000  538000.0       3.0       2.25
# 2           2  5631500400  20150225T000000  180000.0       2.0       1.00
# 3           3  2487200875  20141209T000000  604000.0       4.0       3.00
# 4           4  1954400510  20150218T000000  510000.0       3.0       2.00
#
#    sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# 0         1180      5650     1.0           0  ...      7        1180
# 1         2570      7242     2.0           0  ...      7        2170
# 2          770     10000     1.0           0  ...      6         770
# 3         1960      5000     1.0           0  ...      7        1050
# 4         1680      8080     1.0           0  ...      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0            id         price      bedrooms     bathrooms  \
# count  21613.00000  2.161300e+04  2.161300e+04  21600.000000  21603.000000
# mean   10806.00000  4.580302e+09  5.400881e+05      3.372870      2.115736
# std     6239.28002  2.876566e+09  3.671272e+05      0.926657      0.768996
# min        0.00000  1.000102e+06  7.500000e+04      1.000000      0.500000
# 25%     5403.00000  2.123049e+09  3.219500e+05      3.000000      1.750000
# 50%    10806.00000  3.904930e+09  4.500000e+05      3.000000      2.250000
# 75%    16209.00000  7.308900e+09  6.450000e+05      4.000000      2.500000
# max    21612.00000  9.900000e+09  7.700000e+06     33.000000      8.000000
#
#         sqft_living      sqft_lot        floors    waterfront          view  \
# count  21613.000000  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean    2079.899736  1.510697e+04      1.494309      0.007542      0.234303
# ...

# %%
df = pd.read_csv("housing.csv")

# %%
file_name = "housing.csv"
df = pd.read_csv(file_name)

# %%
df.head()
df.describe()
# Out:
#         Unnamed: 0            id         price      bedrooms     bathrooms  \
# count  21613.00000  2.161300e+04  2.161300e+04  21600.000000  21603.000000
# mean   10806.00000  4.580302e+09  5.400881e+05      3.372870      2.115736
# std     6239.28002  2.876566e+09  3.671272e+05      0.926657      0.768996
# min        0.00000  1.000102e+06  7.500000e+04      1.000000      0.500000
# 25%     5403.00000  2.123049e+09  3.219500e+05      3.000000      1.750000
# 50%    10806.00000  3.904930e+09  4.500000e+05      3.000000      2.250000
# 75%    16209.00000  7.308900e+09  6.450000e+05      4.000000      2.500000
# max    21612.00000  9.900000e+09  7.700000e+06     33.000000      8.000000
#
#         sqft_living      sqft_lot        floors    waterfront          view  \
# count  21613.000000  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean    2079.899736  1.510697e+04      1.494309      0.007542      0.234303
# ...

# %%
# Display the data types of each column
print(df.dtypes)

# Generate statistical summary
print(df.describe())
# Out:
# Unnamed: 0         int64
# id                 int64
# date              object
# price            float64
# bedrooms         float64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object
#         Unnamed: 0            id         price      bedrooms     bathrooms  \
# count  21613.00000  2.161300e+04  2.161300e+04  21600.000000  21603.000000
# mean   10806.00000  4.580302e+09  5.400881e+05      3.372870      2.115736
# std     6239.28002  2.876566e+09  3.671272e+05      0.926657      0.768996
# min        0.00000  1.000102e+06  7.500000e+04      1.000000      0.500000
# ...

# %%
# Drop 'id' and 'Unnamed: 0' columns
df.drop(["id", "Unnamed: 0"], axis=1, inplace=True)

# Show statistical summary
print(df.describe())
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21600.000000  21603.000000  21613.000000  2.161300e+04
# mean   5.400881e+05      3.372870      2.115736   2079.899736  1.510697e+04
# std    3.671272e+05      0.926657      0.768996    918.440897  4.142051e+04
# min    7.500000e+04      1.000000      0.500000    290.000000  5.200000e+02
# 25%    3.219500e+05      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068800e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       1.494309      0.007542      0.234303      3.409430      7.656873
# ...

# %%
print("number of NaN values for the column bedrooms :", df['bedrooms'].isnull().sum())
print("number of NaN values for the column bathrooms :", df['bathrooms'].isnull().sum())
# Out:
# number of NaN values for the column bedrooms : 13
# number of NaN values for the column bathrooms : 10

# %%
# Replace missing values in 'bedrooms'
mean_bedrooms = df['bedrooms'].mean()
df['bedrooms'].replace(np.nan, mean_bedrooms, inplace=True)

# Replace missing values in 'bathrooms'
mean_bathrooms = df['bathrooms'].mean()
df['bathrooms'].replace(np.nan, mean_bathrooms, inplace=True)

# %%
print("number of NaN values for the column bedrooms :", df['bedrooms'].isnull().sum())
print("number of NaN values for the column bathrooms :", df['bathrooms'].isnull().sum())
# Out:
# number of NaN values for the column bedrooms : 0
# number of NaN values for the column bathrooms : 0

# %%
# Count the number of houses with unique floor values
floor_counts = df['floors'].value_counts().to_frame()

# Rename the column for clarity
floor_counts.columns = ['count']

# Display the result
print(floor_counts)
# Out:
#         count
# floors
# 1.0     10680
# 2.0      8241
# 1.5      1910
# 3.0       613
# 2.5       161
# 3.5         8

# %%
# Create a boxplot comparing price distributions based on waterfront view
sns.boxplot(x="waterfront", y="price", data=df)

# Add labels and title for clarity
plt.xlabel("Waterfront (0 = No, 1 = Yes)")
plt.ylabel("Price")
plt.title("House Price Distribution: Waterfront vs No Waterfront")

# Display the plot
plt.show()

# %%
# Plot a regression line between sqft_above and price
sns.regplot(x="sqft_above", y="price", data=df)

# Add axis labels and title
plt.xlabel("Square Footage Above Basement")
plt.ylabel("Price")
plt.title("Correlation between Sqft Above and Price")

# Show the plot
plt.show()

# %%
# Select only numeric columns
df_numeric = df.select_dtypes(include=[np.number])

# Sort correlations with price in ascending order
correlations = df_numeric.corr()['price'].sort_values()

# Display the full list
print(correlations)
# Out:
# zipcode         -0.053203
# long             0.021626
# condition        0.036362
# yr_built         0.054012
# sqft_lot15       0.082447
# sqft_lot         0.089661
# yr_renovated     0.126434
# floors           0.256794
# waterfront       0.266369
# lat              0.307003
# bedrooms         0.308797
# sqft_basement    0.323816
# view             0.397293
# bathrooms        0.525738
# sqft_living15    0.585379
# sqft_above       0.605567
# grade            0.667434
# sqft_living      0.702035
# price            1.000000
# Name: price, dtype: float64

# %%
# Define the feature and target variable
X = df[['sqft_living']]  # Feature
Y = df['price']          # Target

# Create a LinearRegression object
lm = LinearRegression()

# Fit the model
lm.fit(X, Y)

# Calculate and print the R^2 score
r2_score = lm.score(X, Y)
print("R² value:", r2_score)
# Out:
# R² value: 0.4928532179037931

# %%
# Define the feature list
features = ["floors", "waterfront", "lat", "bedrooms", "sqft_basement",
            "view", "bathrooms", "sqft_living15", "sqft_above", "grade", "sqft_living"]

# Create X and Y
X = df[features]
Y = df['price']

# Create and train the Linear Regression model
lm = LinearRegression()
lm.fit(X, Y)

# Calculate R^2 score
r2_score = lm.score(X, Y)
print("R² value using multiple features:", r2_score)
# Out:
# R² value using multiple features: 0.6576890354915759

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import LinearRegression

# Define the feature list
features = ["floors", "waterfront", "lat", "bedrooms", "sqft_basement",
            "view", "bathrooms", "sqft_living15", "sqft_above", "grade", "sqft_living"]

# Create input list of tuples
Input = [('scale', StandardScaler()),
         ('polynomial', PolynomialFeatures(include_bias=False)),
         ('model', LinearRegression())]

# Create pipeline object
pipe = Pipeline(Input)

# Fit the pipeline model using features and target
pipe.fit(df[features], df['price'])

# Calculate R^2 score
r2_score = pipe.score(df[features], df['price'])
print("R² value using pipeline with polynomial features:", r2_score)
# Out:
# R² value using pipeline with polynomial features: 0.7512051345272872

# %%
from sklearn.linear_model import Ridge

# Create Ridge regression object with alpha = 0.1
ridge_model = Ridge(alpha=0.1)

# Fit the model using training data
ridge_model.fit(x_train, y_train)

# Calculate R² using test data
r2_score = ridge_model.score(x_test, y_test)
print("R² value using Ridge regression:", r2_score)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 7
#       4 ridge_model = Ridge(alpha=0.1)
#       6 # Fit the model using training data
# ----> 7 ridge_model.fit(x_train, y_train)
#       9 # Calculate R² using test data
#      10 r2_score = ridge_model.score(x_test, y_test)
#
# NameError: name 'x_train' is not defined

# %%
# Import necessary libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge

# Define features and target
features = ["floors", "waterfront", "lat", "bedrooms", "sqft_basement", 
            "view", "bathrooms", "sqft_living15", "sqft_above", "grade", "sqft_living"]
X = df[features]
Y = df['price']

# Split into training and test sets
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.15, random_state=1)

# Create and train Ridge regression model
ridge_model = Ridge(alpha=0.1)
ridge_model.fit(x_train, y_train)

# Evaluate R² score
r2_score = ridge_model.score(x_test, y_test)
print("R² value using Ridge regression:", r2_score)
# Out:
# R² value using Ridge regression: 0.647875916393907

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import Ridge

# Perform 2nd order polynomial transformation
poly = PolynomialFeatures(degree=2)
x_train_poly = poly.fit_transform(x_train)
x_test_poly = poly.transform(x_test)

# Create and fit Ridge regression model
ridge_model = Ridge(alpha=0.1)
ridge_model.fit(x_train_poly, y_train)

# Evaluate R² score
r2_poly = ridge_model.score(x_test_poly, y_test)
print("R² value with Polynomial Ridge regression:", r2_poly)
# Out:
# R² value with Polynomial Ridge regression: 0.7002744263583341
